# %% [markdown]
# ## OGUNWALE OLUREMI ITUNU
# UDACITY Project 2 JUNE 2022

# %% [markdown]
# #                                        WeRateDogs Twitter Archive - Act Report
# Data Gathering
#
# The WeRateDogs Enhanced Twitter archive contains data extracted from 2356 of the 5000+ tweets from the @dog_rates twitter account, posted between November 15, 2015 and August 1, 2017. This data is comprised of dog ratings that were taken from the text of the tweet along with the dog name and dog stages. The retweet count and favourite count for each tweet were not included in the enhanced archive, and so I was meant to download this additional data from the twitter account using the tweet ID from the archive but instead i loaded the provided text file by udacity and read it into a dataframe because the twitter API had an issues, so it was inaccessible to get the API key for twitter to scrap this data. Along with the Twitter data, I also downloaded an image predictions file from Udacity servers containing the
# top 3 predictions for dog breeds based on the images from the tweets.
#
# Wrangling Data
#
# Before I could begin the analysis, the data had to be wrangled into shape to make it easier. I assessed the data both visually and programmatically for quality and tidiness; the quality of data is determined mainly by looking at several aspects or dimensions to ensure that it is complete, valid, accurate and consistent. After cleaning many of the issues found during the assessment, there were about 1506 tweets with good quality data.
#
# Insights
#
# 1. Top dog stages with the highest fav counts
#
# In our dataset, it showed that people loved dogs that are in the pupper stage because pupper dog stages had the highest favourite count followed by doggo. From my personal experience i find pupper dogs cute because they are small yet sassy and they do not bark. Doggo dogs too are cute and street smart.
#
# ![image-4.png](attachment:image-4.png)
# TOP DOG STAGES WITH THE HIGHEST FAV COUNT
#
# dog_stages
#
# pupper    936001.0
#
# doggo     737573.0
#
# puppo     210339.0
#
# Name: favorite_count, dtype: float64
#
# 2. Relationship between favourite and retweet counts
#
# Favourite Counts Are Higher Than Retweet Counts. One of the simplest insights was that ALL tweets have higher favourite counts than retweet counts. From personal experience,  I am more likely to favourite a tweet than retweet it and there are no correlation between favourite count and retweet count. Plotting these two values against each other produced the plot below, and clearly shows a zero correlation by the very tight collection of points along the angled, straight line and less points on the otherside.
#
# ![image-3.png](attachment:image-3.png)
#
# 3. The source with the highest count.
#
# Twitter for iphone had the highest source counts, so its safe to say that people who uses iphone contributed more to the dog ratings data. There are other sources like 'twitter for web', 'vine', 'tweet deck'
#
# ![image-2.png](attachment:image-2.png)
#
# 4. Favourite counts over time
#
# This shows that over time the account was created, it clearly shows that the twitter account followers were active, and possibly growing, during the timeframe represented in the archive. In the plot below, the slope of the line is increasing at a steady rate from around 2015-11, reflecting the montly increase in tweets being favourited.
#
# ![image.png](attachment:image.png)
